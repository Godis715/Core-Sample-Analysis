# %%
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np
import pandas as pd
from openpyxl import load_workbook
from PIL import Image, ImageStat

# %%
wb = load_workbook('Послойное описание с фотографиями.xlsx')
ws = wb[wb.sheetnames[0]]
df = pd.DataFrame(ws.values).loc[4:56,14:17]
df.head(53)
# Out:
#                                       14  \
# 4                               песчаник
# 5                              алевролит
# 6                               песчаник
# 7   пересл. песчаника, алевролита и глин
# 8                               песчаник
# 9   пересл. песчаника, алевролита и глин
# 10                              песчаник
# 11                             алевролит
# 12                              песчаник
# 13                              песчаник
# 14                              песчаник
# 15                             алевролит
# 16                              песчаник
# 17                             алевролит
# 18  пересл. песчаника, алевролита и глин
# 19  пересл. песчаника, алевролита и глин
# 20                              песчаник
# 21  пересл. песчаника, алевролита и глин
# 22                              песчаник
# 23                              песчаник
# 24                              песчаник
# 25  пересл. песчаника, алевролита и глин
# 26                              песчаник
# 27                              песчаник
# 28                              песчаник
# 29                             алевролит
# 30                             алевролит
# 31                              песчаник
# 32                             алевролит
# 33  пересл. песчаника, алевролита и глин
# 34                              песчаник
# 35                              песчаник
# 36                              песчаник
# 37                              песчаник
# 38                              песчаник
# 39                              песчаник
# 40                              песчаник
# 41                              песчаник
# 42                              песчаник
# 43  пересл. песчаника, алевролита и глин
# 44                              песчаник
# 45  пересл. песчаника, алевролита и глин
# 46  пересл. песчаника, алевролита и глин
# 47                              песчаник
# 48                              песчаник
# 49                              песчаник
# 50                              песчаник
# 51                              песчаник
# 52                              песчаник
# 53                              песчаник
# 54                              песчаник
# 55                              песчаник
#
#                                           15           16  \
# 4                             не карбонатный  не разрушен
# 5                             не карбонатный  не разрушен
# 6                             не карбонатный  не разрушен
# 7                             не карбонатный  не разрушен
# 8                             не карбонатный  не разрушен
# 9                             не карбонатный  не разрушен
# 10                            не карбонатный  не разрушен
# 11                            не карбонатный  не разрушен
# 12                            не карбонатный  не разрушен
# 13                            не карбонатный  не разрушен
# 14                            не карбонатный  не разрушен
# 15                            не карбонатный  не разрушен
# 16                            не карбонатный  не разрушен
# 17                            не карбонатный  не разрушен
# 18                            не карбонатный  не разрушен
# 19                            не карбонатный  не разрушен
# 20                            не карбонатный  не разрушен
# 21                            не карбонатный  не разрушен
# 22                            не карбонатный  не разрушен
# 23                         сильнокарбонатный  не разрушен
# 24                            не карбонатный  не разрушен
# 25                            не карбонатный  не разрушен
# 26                            не карбонатный  не разрушен
# 27                          слабокарбонатный  не разрушен
# 28                            не карбонатный  не разрушен
# 29  с карбонатными обломками или конкрециями  не разрушен
# 30  с карбонатными обломками или конкрециями  не разрушен
# 31                            не карбонатный  не разрушен
# 32                            не карбонатный  не разрушен
# 33                            не карбонатный  не разрушен
# 34  с карбонатными обломками или конкрециями  не разрушен
# 35                         среднекарбонатный  не разрушен
# 36  с карбонатными обломками или конкрециями  не разрушен
# 37  с карбонатными обломками или конкрециями  не разрушен
# 38                            не карбонатный  не разрушен
# 39  с карбонатными обломками или конкрециями  не разрушен
# 40                            не карбонатный  не разрушен
# 41                            не карбонатный  не разрушен
# 42                         сильнокарбонатный  не разрушен
# 43                         сильнокарбонатный  не разрушен
# 44                         сильнокарбонатный  не разрушен
# 45                            не карбонатный  не разрушен
# 46                         сильнокарбонатный  не разрушен
# 47                         среднекарбонатный  не разрушен
# 48                         среднекарбонатный  не разрушен
# 49                            не карбонатный  не разрушен
# 50                          слабокарбонатный  не разрушен
# 51                         сильнокарбонатный  не разрушен
# 52                            не карбонатный  не разрушен
# 53                            не карбонатный  не разрушен
# 54                            не карбонатный  не разрушен
# 55                            не карбонатный  не разрушен
#
#                           17
# 4            нефтенасыщенные
# 5                  не опред.
# 6      слабо нефтенасыщенные
# 7   пятнисто нефтенасыщенные
# 8      слабо нефтенасыщенные
# 9   пятнисто нефтенасыщенные
# 10     слабо нефтенасыщенные
# 11                 не опред.
# 12     слабо нефтенасыщенные
# 13     слабо нефтенасыщенные
# 14     слабо нефтенасыщенные
# 15                 не опред.
# 16     слабо нефтенасыщенные
# 17  пятнисто нефтенасыщенные
# 18  пятнисто нефтенасыщенные
# 19  пятнисто нефтенасыщенные
# 20     слабо нефтенасыщенные
# 21  пятнисто нефтенасыщенные
# 22     слабо нефтенасыщенные
# 23                 не опред.
# 24     слабо нефтенасыщенные
# 25  пятнисто нефтенасыщенные
# 26     слабо нефтенасыщенные
# 27                 не опред.
# 28     слабо нефтенасыщенные
# 29  пятнисто нефтенасыщенные
# 30                 не опред.
# 31  пятнисто нефтенасыщенные
# 32                 не опред.
# 33  пятнисто нефтенасыщенные
# 34  пятнисто нефтенасыщенные
# 35                 не опред.
# 36                 не опред.
# 37  пятнисто нефтенасыщенные
# 38     слабо нефтенасыщенные
# 39  пятнисто нефтенасыщенные
# 40     слабо нефтенасыщенные
# 41  пятнисто нефтенасыщенные
# 42                 не опред.
# 43                 не опред.
# 44                 не опред.
# 45                 не опред.
# 46                 не опред.
# 47  пятнисто нефтенасыщенные
# 48                 не опред.
# 49     слабо нефтенасыщенные
# 50     слабо нефтенасыщенные
# 51  пятнисто нефтенасыщенные
# 52     слабо нефтенасыщенные
# 53           нефтенасыщенные
# 54           нефтенасыщенные
# 55           нефтенасыщенные

# %%
oil_imgs=[]
path = 'pics/'
i = 0
for row in df.itertuples():
    i += 1
    title=str(i+4)+' УФ\n'+row[2]+'\n'+row[4]
    #if 'не карбонатный' in row[2]:
    #    continue
    elems = []
    for elem in os.listdir(path+str(i)):
        elems.append(path+str(i)+'/'+elem)
    src = elems[:int(len(elems)/2)]
    uv = elems[int(len(elems)/2):]
    src = np.concatenate([cv2.imread(img,1) for img in src], axis=0)
    uv = np.concatenate([cv2.imread(img,1) for img in uv], axis=0)
    img_dn = cv2.fastNlMeansDenoisingColored(uv, h=10) 
    #img_dn = cv2.resize(img_dn,None,fx=1,fy=2,interpolation=cv2.INTER_CUBIC)
    img_rgb = cv2.cvtColor(img_dn, cv2.COLOR_BGR2RGB)
    img_hsv = cv2.cvtColor(img_dn, cv2.COLOR_BGR2HSV)
    #img_h = np.array([[[x[0],255,255] for x in y] for y in img_hsv])
    pil_img = Image.fromarray(img_rgb)
    bright = sum(ImageStat.Stat(pil_img).mean) // 3
    img_gray = cv2.cvtColor(img_dn,cv2.COLOR_BGR2GRAY)
    dark = (85*(bright/85),100*(bright/85),100*(bright/85))
    light = (255,255,255)
    mask_yel = cv2.inRange(img_rgb, dark, light)
    img_yel = cv2.bitwise_and(img_gray, img_gray, mask=mask_yel)
    img_yel = cv2.GaussianBlur(img_yel, (5,5), 0)
    oil_imgs.append(img_yel)
    thresh = (0,0,10)
    mask_thresh = cv2.inRange(img_hsv, thresh, (180,255,255))
    img_hsv = cv2.bitwise_and(img_hsv, img_hsv, mask=mask_thresh)
    pil_img2 = Image.fromarray(img_hsv)
    mean_stat = ImageStat.Stat(pil_img2).mean
    mean_hue = mean_stat[0]
    mean_sat = mean_stat[1]
    mean_val = mean_stat[2]
    dark = (0,10,10)
    light = (30,255,255)
    mask_red = cv2.inRange(img_hsv, dark, light)
    img_red = cv2.bitwise_and(img_gray, img_gray, mask=mask_red)
    img_red = cv2.GaussianBlur(img_red, (5,5), 0)
    '''
    fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(1, 5, figsize=(15,100), sharex=True, sharey=True)

    ax1.imshow(img_rgb)
    ax1.set_title(title+'\nRGB Denoised\nMean Hue: '+str(mean_hue)+
                  '\nMean Saturation: '+str(mean_sat)+'\nMean Value: '+str(mean_val))
        
    ax2.imshow(img_gray)
    ax2.set_title('Gray')
    
    ax4.imshow(img_yel, cmap='gray')
    ax4.set_title('Oil mask')
    
    ax3.imshow(img_hsv)
    ax3.set_title('HSV (Value=10+)')
    
    ax5.imshow(img_red, cmap='gray')
    ax5.set_title('Carbon mask')
    plt.show()
    '''

# %%
def surf(img):
    surf = cv2.xfeatures2d.SURF_create(2000)
    kp, des = surf.detectAndCompute(img,None)
    return cv2.drawKeypoints(img,kp,None,(255,0,0),4)

# %%
opil_imgs = [Image.fromarray(img) for img in oil_imgs]
oil_means = [sum(ImageStat.Stat(img).mean) for img in opil_imgs]
df['Oil Means'] = oil_means

# %%
best_cor = 0
par = 5
step = 0.01
df['Oil Preds'] = [0]*52
for p in np.arange(5.,50.,step):
    oil_preds = [1 if mean > p else 0 for mean in oil_means]
    cor = 0
    i = 0
    for row in df.itertuples():
        if row[4] == 'не опред.':
            if oil_preds[i] == 0:
                cor += 1
        else:
            if oil_preds[i] == 1:
                cor += 1
        i += 1
    if cor > best_cor:
        par = p - step
        best_cor = cor
        df['Oil Preds'] = oil_preds
    
print('param: ', par)
print('correct: ', best_cor)
print('accuracy: ', best_cor/52.)
# Out:
# param:  7.899999999999938
# correct:  43
# accuracy:  0.8269230769230769

# %%
def area_part(arr):
    pxls = sum([sum([0 if pxl == 0 else 1 for pxl in row])for row in arr])
    return pxls/(len(arr)*len(arr[0]))
oil_areas = [area_part(img) for img in oil_imgs]
df['Oil Areas'] = oil_areas

# %%
best_cor = 0
par = 0
step = 0.005
df['Oil Preds #2'] = [0]*52
for p in np.arange(0.,1.,step):
    oil_area_preds = [1 if area > p else 0 for area in oil_areas]
    cor = 0
    i = 0
    for row in df.itertuples():
        if row[4] == 'не опред.':
            if oil_area_preds[i] == 0:
                cor += 1
        else:
            if oil_area_preds[i] == 1:
                cor += 1
        i += 1
    if cor > best_cor:
        par = p - step
        best_cor = cor
        df['Oil Preds #2'] = oil_area_preds
print('param: ', par)
print('correct: ', best_cor)
print('accuracy: ', best_cor/52.)
# Out:
# param:  0.265
# correct:  44
# accuracy:  0.8461538461538461

# %%
df.head(53)
# Out:
#                                       14  \
# 4                               песчаник
# 5                              алевролит
# 6                               песчаник
# 7   пересл. песчаника, алевролита и глин
# 8                               песчаник
# 9   пересл. песчаника, алевролита и глин
# 10                              песчаник
# 11                             алевролит
# 12                              песчаник
# 13                              песчаник
# 14                              песчаник
# 15                             алевролит
# 16                              песчаник
# 17                             алевролит
# 18  пересл. песчаника, алевролита и глин
# 19  пересл. песчаника, алевролита и глин
# 20                              песчаник
# 21  пересл. песчаника, алевролита и глин
# 22                              песчаник
# 23                              песчаник
# 24                              песчаник
# 25  пересл. песчаника, алевролита и глин
# 26                              песчаник
# 27                              песчаник
# 28                              песчаник
# 29                             алевролит
# 30                             алевролит
# 31                              песчаник
# 32                             алевролит
# 33  пересл. песчаника, алевролита и глин
# 34                              песчаник
# 35                              песчаник
# 36                              песчаник
# 37                              песчаник
# 38                              песчаник
# 39                              песчаник
# 40                              песчаник
# 41                              песчаник
# 42                              песчаник
# 43  пересл. песчаника, алевролита и глин
# 44                              песчаник
# 45  пересл. песчаника, алевролита и глин
# 46  пересл. песчаника, алевролита и глин
# 47                              песчаник
# 48                              песчаник
# 49                              песчаник
# 50                              песчаник
# 51                              песчаник
# 52                              песчаник
# 53                              песчаник
# 54                              песчаник
# 55                              песчаник
#
#                                           15           16  \
# 4                             не карбонатный  не разрушен
# 5                             не карбонатный  не разрушен
# 6                             не карбонатный  не разрушен
# 7                             не карбонатный  не разрушен
# 8                             не карбонатный  не разрушен
# 9                             не карбонатный  не разрушен
# 10                            не карбонатный  не разрушен
# 11                            не карбонатный  не разрушен
# 12                            не карбонатный  не разрушен
# 13                            не карбонатный  не разрушен
# 14                            не карбонатный  не разрушен
# 15                            не карбонатный  не разрушен
# 16                            не карбонатный  не разрушен
# 17                            не карбонатный  не разрушен
# 18                            не карбонатный  не разрушен
# 19                            не карбонатный  не разрушен
# 20                            не карбонатный  не разрушен
# 21                            не карбонатный  не разрушен
# 22                            не карбонатный  не разрушен
# 23                         сильнокарбонатный  не разрушен
# 24                            не карбонатный  не разрушен
# 25                            не карбонатный  не разрушен
# 26                            не карбонатный  не разрушен
# 27                          слабокарбонатный  не разрушен
# 28                            не карбонатный  не разрушен
# 29  с карбонатными обломками или конкрециями  не разрушен
# 30  с карбонатными обломками или конкрециями  не разрушен
# 31                            не карбонатный  не разрушен
# 32                            не карбонатный  не разрушен
# 33                            не карбонатный  не разрушен
# 34  с карбонатными обломками или конкрециями  не разрушен
# 35                         среднекарбонатный  не разрушен
# 36  с карбонатными обломками или конкрециями  не разрушен
# 37  с карбонатными обломками или конкрециями  не разрушен
# 38                            не карбонатный  не разрушен
# 39  с карбонатными обломками или конкрециями  не разрушен
# 40                            не карбонатный  не разрушен
# 41                            не карбонатный  не разрушен
# 42                         сильнокарбонатный  не разрушен
# 43                         сильнокарбонатный  не разрушен
# 44                         сильнокарбонатный  не разрушен
# 45                            не карбонатный  не разрушен
# 46                         сильнокарбонатный  не разрушен
# 47                         среднекарбонатный  не разрушен
# 48                         среднекарбонатный  не разрушен
# 49                            не карбонатный  не разрушен
# 50                          слабокарбонатный  не разрушен
# 51                         сильнокарбонатный  не разрушен
# 52                            не карбонатный  не разрушен
# 53                            не карбонатный  не разрушен
# 54                            не карбонатный  не разрушен
# 55                            не карбонатный  не разрушен
#
#                           17   Oil Means  Oil Preds  Oil Areas  Oil Preds #2
# 4            нефтенасыщенные   31.534172          1   0.562649             1
# 5                  не опред.    6.488578          0   0.296743             1
# 6      слабо нефтенасыщенные   43.689167          1   0.443583             1
# 7   пятнисто нефтенасыщенные   10.116250          1   0.607500             1
# 8      слабо нефтенасыщенные   42.058550          1   0.438779             1
# 9   пятнисто нефтенасыщенные   25.139610          1   0.631299             1
# 10     слабо нефтенасыщенные    4.570323          0   0.197742             0
# 11                 не опред.   34.654000          1   0.530160             1
# 12     слабо нефтенасыщенные   21.743548          1   0.375323             1
# 13     слабо нефтенасыщенные   33.183692          1   0.421231             1
# 14     слабо нефтенасыщенные   68.304593          1   0.413111             1
# 15                 не опред.    2.421346          0   0.182500             0
# 16     слабо нефтенасыщенные   37.944085          1   0.728592             1
# 17  пятнисто нефтенасыщенные   34.777368          1   0.699649             1
# 18  пятнисто нефтенасыщенные   27.573333          1   0.678810             1
# 19  пятнисто нефтенасыщенные   29.941007          1   0.660072             1
# 20     слабо нефтенасыщенные   37.960114          1   0.493636             1
# 21  пятнисто нефтенасыщенные   36.504522          1   0.617217             1
# 22     слабо нефтенасыщенные   25.530976          1   0.808780             1
# 23                 не опред.    1.234254          0   0.052761             0
# 24     слабо нефтенасыщенные   64.998914          1   0.565339             1
# 25  пятнисто нефтенасыщенные   52.191125          1   0.702250             1
# 26     слабо нефтенасыщенные   52.304138          1   0.659483             1
# 27                 не опред.   13.475625          1   0.578750             1
# 28     слабо нефтенасыщенные   76.089231          1   0.583974             1
# 29  пятнисто нефтенасыщенные    3.991429          0   0.263069             0
# 30                 не опред.    3.355725          0   0.254783             0
# 31  пятнисто нефтенасыщенные    9.541165          1   0.409223             1
# 32                 не опред.    4.219538          0   0.245538             0
# 33  пятнисто нефтенасыщенные   11.646837          1   0.475639             1
# 34  пятнисто нефтенасыщенные   42.765775          1   0.723814             1
# 35                 не опред.    5.256875          0   0.215250             0
# 36                 не опред.    6.359503          0   0.205635             0
# 37  пятнисто нефтенасыщенные   27.750625          1   0.575664             1
# 38     слабо нефтенасыщенные  116.701667          1   0.716333             1
# 39  пятнисто нефтенасыщенные   47.771842          1   0.581184             1
# 40     слабо нефтенасыщенные  148.592941          1   0.789412             1
# 41  пятнисто нефтенасыщенные   65.040156          1   0.743047             1
# 42                 не опред.   18.552044          1   0.266642             0
# 43                 не опред.    7.906500          0   0.264125             0
# 44                 не опред.   11.384070          1   0.195930             0
# 45                 не опред.   25.404242          1   0.340909             1
# 46                 не опред.   28.426618          1   0.352500             1
# 47  пятнисто нефтенасыщенные   35.341014          1   0.369710             1
# 48                 не опред.   11.576591          1   0.215682             0
# 49     слабо нефтенасыщенные   46.618954          1   0.285508             1
# 50     слабо нефтенасыщенные   37.260206          1   0.314863             1
# 51  пятнисто нефтенасыщенные   82.070897          1   0.628974             1
# 52     слабо нефтенасыщенные   49.491051          1   0.299670             1
# 53           нефтенасыщенные   35.414359          1   0.341422             1
# 54           нефтенасыщенные    9.280918          1   0.155357             0
# 55           нефтенасыщенные   40.302157          1   0.365686             1

# %%
X = [[oil_means[i], oil_areas[i]] for i in range(len(oil_means))]
y = [0. if oil=='не опред.' else 1. for oil in df[17]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=10, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)
model.fit(X_train, y_train)
preds = model.predict(X_test)
c = 0
for i in range(len(preds)):
    if preds[i] > 0.5:
        if y_test[i] == 1:
            c += 1
    else:
        if y_test[i] == 0:
            c += 1

print(c/len(preds))
# Out:
# 0.8571428571428571

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score

xgb_model = XGBRegressor(n_estimators=10, learning_rate=0.5)
scores = -1 * cross_val_score(xgb_model, X, y,
                              cv=5,
                              scoring='neg_mean_absolute_error')
print('MAE: ', scores.mean())
xgb_model.fit(X_train, y_train)
preds = xgb_model.predict(X_test)
c = 0
for i in range(len(preds)):
    if preds[i] > 0.5:
        if y_test[i] == 1:
            c += 1
    else:
        if y_test[i] == 0:
            c += 1
            
print(c/len(preds))
# Out:
# [02:54:17] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:54:17] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:54:17] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:54:17] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:54:17] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MAE:  0.3415192663669586
# [02:54:17] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.7142857142857143
