# %%
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np
import pandas as pd
from openpyxl import load_workbook
from PIL import Image, ImageStat

# %%
wb = load_workbook('Послойное описание с фотографиями.xlsx')
ws = wb[wb.sheetnames[0]]
df = pd.DataFrame(ws.values).loc[4:56,14:17]
df = df.rename(columns={14:'Порода', 15:'Карбонатность', 16:'Разрушенность', 17:'Насыщение'})

# %%
pics = {}
path = 'pics/'

for row in df.itertuples():
    elems = []
    for elem in os.listdir(path+str(row[0]-3)):
        elems.append(path+str(row[0]-3)+'/'+elem)
    src = elems[:int(len(elems)/2)]
    uv = elems[int(len(elems)/2):]
    src = np.concatenate([cv2.imread(img,1) for img in src], axis=0)
    uv = np.concatenate([cv2.imread(img,1) for img in uv], axis=0)
    pics[row[0]] = [ cv2.cvtColor(src, cv2.COLOR_BGR2RGB), 
                    cv2.cvtColor(uv, cv2.COLOR_BGR2RGB) ]

# %%
def get_oil_features(imgs):
    oil_features = []
    
    for img in imgs:
        pil_img = Image.fromarray(img)
        bright = sum(ImageStat.Stat(pil_img).mean) // 3
        dark = (85*(bright/85), 100*(bright/85), 100*(bright/85))
        light = (255, 255, 255)
        mask_yel = cv2.inRange(img, dark, light)
        img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        img_yel = cv2.bitwise_and(img_gray, img_gray, mask=mask_yel)
        pil_img_yel = Image.fromarray(img_yel)
        size = len(img) * len(img[0])
        area = sum([sum([0 if pxl == 0 else 1 for pxl in row])for row in img_yel])
        feature = {}
        #feature['size'] = len(img) * len(img[0])
        feature['area'] = area / size
        #feature['bright'] = bright
        feature['mean'] = sum([sum([pxl for pxl in row]) for row in img_yel]) / (area*bright)
        oil_features.append(feature)
    
    return oil_features

# %%
oil_features = get_oil_features([value[1] for value in pics.values()])
df['oil_features'] = oil_features
df.head(53)
# Out:
#                                   Порода  \
# 4                               песчаник
# 5                              алевролит
# 6                               песчаник
# 7   пересл. песчаника, алевролита и глин
# 8                               песчаник
# 9   пересл. песчаника, алевролита и глин
# 10                              песчаник
# 11                             алевролит
# 12                              песчаник
# 13                              песчаник
# 14                              песчаник
# 15                             алевролит
# 16                              песчаник
# 17                             алевролит
# 18  пересл. песчаника, алевролита и глин
# 19  пересл. песчаника, алевролита и глин
# 20                              песчаник
# 21  пересл. песчаника, алевролита и глин
# 22                              песчаник
# 23                              песчаник
# 24                              песчаник
# 25  пересл. песчаника, алевролита и глин
# 26                              песчаник
# 27                              песчаник
# 28                              песчаник
# 29                             алевролит
# 30                             алевролит
# 31                              песчаник
# 32                             алевролит
# 33  пересл. песчаника, алевролита и глин
# 34                              песчаник
# 35                              песчаник
# 36                              песчаник
# 37                              песчаник
# 38                              песчаник
# 39                              песчаник
# 40                              песчаник
# 41                              песчаник
# 42                              песчаник
# 15                 не опред.
# 16     слабо нефтенасыщенные
# 17  пятнисто нефтенасыщенные
# 18  пятнисто нефтенасыщенные
# 19  пятнисто нефтенасыщенные
# 20     слабо нефтенасыщенные
# 21  пятнисто нефтенасыщенные
# 22     слабо нефтенасыщенные
# 23                 не опред.
# 24     слабо нефтенасыщенные
# 25  пятнисто нефтенасыщенные
# 26     слабо нефтенасыщенные
# 27                 не опред.
# 28     слабо нефтенасыщенные
# 29  пятнисто нефтенасыщенные
# 30                 не опред.
# 31  пятнисто нефтенасыщенные
# 32                 не опред.
# 33  пятнисто нефтенасыщенные
# 34  пятнисто нефтенасыщенные
# 35                 не опред.
# 36                 не опред.
# 37  пятнисто нефтенасыщенные
# 38     слабо нефтенасыщенные
# 39  пятнисто нефтенасыщенные
# 40     слабо нефтенасыщенные
# 41  пятнисто нефтенасыщенные
# 42                 не опред.
# 43                 не опред.
# 44                 не опред.
# 45                 не опред.
# 46                 не опред.
# 47  пятнисто нефтенасыщенные
# 48                 не опред.
# 49     слабо нефтенасыщенные
# 50     слабо нефтенасыщенные
# 51  пятнисто нефтенасыщенные
# 52     слабо нефтенасыщенные
# 53           нефтенасыщенные
# 54           нефтенасыщенные
# 55           нефтенасыщенные
#
#                                          oil_features
# 4   {'area': 0.24291390728476822, 'mean': 1.990411...
# 5   {'area': 0.13807339449541284, 'mean': 2.623168...
# 6   {'area': 0.2994583333333333, 'mean': 1.7854128...
# 7        {'area': 0.24625, 'mean': 2.057161774442728}
# 8   {'area': 0.25641221374045803, 'mean': 1.507021...
# 9   {'area': 0.2885714285714286, 'mean': 2.0340936...
# 10  {'area': 0.12838709677419355, 'mean': 1.508317...
# 11      {'area': 0.33168, 'mean': 1.8062738352037426}
# 12  {'area': 0.20016129032258065, 'mean': 1.587312...
# 13  {'area': 0.24846153846153846, 'mean': 1.873241...
# 14  {'area': 0.29933333333333334, 'mean': 1.292766...
# 15  {'area': 0.16192307692307692, 'mean': 1.809085...
# 16  {'area': 0.32577464788732396, 'mean': 2.089148...
# 17  {'area': 0.28385964912280703, 'mean': 2.349802...
# 18  {'area': 0.2783333333333333, 'mean': 2.3020072...
# 19  {'area': 0.26402877697841726, 'mean': 2.526333...
# 20  {'area': 0.27051136363636363, 'mean': 1.580563...
# 21  {'area': 0.32582608695652177, 'mean': 1.850515...
# 22  {'area': 0.2924390243902439, 'mean': 1.8613288...
# 23  {'area': 0.024402985074626866, 'mean': 1.74021...
# 24  {'area': 0.35321266968325793, 'mean': 1.580437...
# 25      {'area': 0.33925, 'mean': 1.8707028371407517}
# 26  {'area': 0.3024137931034483, 'mean': 1.5882948...
# 27     {'area': 0.234375, 'mean': 1.7776761904761904}
# 28  {'area': 0.3433333333333333, 'mean': 1.4490863...
# 29  {'area': 0.18984126984126984, 'mean': 1.827968...
# 30  {'area': 0.17028985507246377, 'mean': 1.934184...
# 31  {'area': 0.20242718446601943, 'mean': 2.425755...
# 32  {'area': 0.14261538461538462, 'mean': 2.266527...
# 33  {'area': 0.21709233791748528, 'mean': 2.394031...
# 34  {'area': 0.30474576271186443, 'mean': 1.960416...
# 35      {'area': 0.12425, 'mean': 1.7611382581201496}
# 36  {'area': 0.13922651933701657, 'mean': 2.709085...
# 37  {'area': 0.2430078125, 'mean': 2.684990448705248}
# 38  {'area': 0.4116666666666667, 'mean': 1.2715658...
# 39  {'area': 0.26105263157894737, 'mean': 2.523031...
# 40  {'area': 0.5617647058823529, 'mean': 1.2835969...
# 41   {'area': 0.391171875, 'mean': 1.935464467392709}
# 42  {'area': 0.16262773722627738, 'mean': 2.882540...
# 43     {'area': 0.144625, 'mean': 2.4728435609334487}
# 44  {'area': 0.1213953488372093, 'mean': 2.8909736...
# 45  {'area': 0.18272727272727274, 'mean': 2.778441...
# 46  {'area': 0.19661764705882354, 'mean': 2.678315...
# 47  {'area': 0.22797101449275362, 'mean': 2.688186...
# 48  {'area': 0.12818181818181817, 'mean': 2.793178...
# 49  {'area': 0.24341538461538462, 'mean': 1.202684...
# 50  {'area': 0.21278350515463917, 'mean': 1.429817...
# 51  {'area': 0.4255128205128205, 'mean': 1.6641732...
# 52  {'area': 0.23453453453453454, 'mean': 1.281381...
# 53  {'area': 0.22806526806526806, 'mean': 1.468103...
# 54  {'area': 0.09852040816326531, 'mean': 1.395664...
# 55  {'area': 0.2265686274509804, 'mean': 1.4174578...

# %%
X = [list(feature.values()) for feature in df['oil_features']]
y = [0. if oil=='не опред.' else 1. for oil in df['Насыщение']]

# %%
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.model_selection import ShuffleSplit, cross_val_score

cv = ShuffleSplit(n_splits=50, test_size=0.3, random_state=0)

# %%
def score(model, X, y, cv):
    scores = cross_val_score(model, X, y,
                              cv=cv,
                              scoring=make_scorer(accuracy_score))
    return scores.mean()

# %%
ada = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),
                         algorithm="SAMME",
                         n_estimators=10, 
                         learning_rate=1, random_state=0)
print('AdaBoost: ', score(ada, X, y, cv))

rfc = RandomForestClassifier(n_estimators=10, 
                             random_state=0)
print('RandomForestClassifier: ', score(rfc, X, y, cv))

gbc = GradientBoostingClassifier(n_estimators=10, random_state=0)
print('GradientBoostingClassifier: ', score(gbc, X, y, cv))
# Out:
# AdaBoost:  0.86625
# RandomForestClassifier:  0.875
# GradientBoostingClassifier:  0.865

# %%
print(ada.fit(X,y).feature_importances_)
print(rfc.fit(X,y).feature_importances_)
print(gbc.fit(X,y).feature_importances_)
# Out:
# [0.31718013 0.68281987]
# [0.46691348 0.53308652]
# [0.70964624 0.29035376]
